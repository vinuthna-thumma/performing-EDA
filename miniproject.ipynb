# %%
import pandas as pd

# %%
df=pd.read_csv('/content/DataCoSupplyChainDataset.csv', engine='python')

# %%
df
# Out:
#             Type  ...   Shipping Mode
# 0          DEBIT  ...  Standard Class
# 1       TRANSFER  ...  Standard Class
# 2           CASH  ...  Standard Class
# 3          DEBIT  ...  Standard Class
# 4        PAYMENT  ...  Standard Class
# ...          ...  ...             ...
# 180514      CASH  ...  Standard Class
# 180515     DEBIT  ...    Second Class
# 180516  TRANSFER  ...  Standard Class
# 180517   PAYMENT  ...  Standard Class
# 180518   PAYMENT  ...  Standard Class
#
# [180519 rows x 53 columns]

# %%
df.describe()
# Out:
#        Days for shipping (real)  ...  Product Status
# count             180519.000000  ...        180519.0
# mean                   3.497654  ...             0.0
# std                    1.623722  ...             0.0
# min                    0.000000  ...             0.0
# 25%                    2.000000  ...             0.0
# 50%                    3.000000  ...             0.0
# 75%                    5.000000  ...             0.0
# max                    6.000000  ...             0.0
#
# [8 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df.drop('Product Description',axis='columns', inplace=True)

# %%
df.drop('Order Zipcode',axis='columns',inplace=True)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df=df[['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
       'Benefit per order', 'Sales per customer','Customer Id','Order City', 'Order Country', 'Order Customer Id',
       'order date (DateOrders)', 'Order Id', 'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
       'Order Item Product Price', 'Order Item Profit Ratio',
       'Order Item Quantity', 'Sales','Order Item Total',
       'Order Profit Per Order','Order Region',
       'Delivery Status','Late_delivery_risk','Customer State', 'Customer Street', 'Customer Zipcode',
       'Customer City','Customer Country','Order Status',
       'Product Card Id', 'Product Category Id', 'Product Image',
       'Product Name', 'Product Price','shipping date (DateOrders)', 'Shipping Mode']]

# %%
df.shape
# Out:
# (180508, 36)

# %%
duplicate_rows_df=df[df.duplicated()]

# %%
duplicate_rows_df
# Out:
# Empty DataFrame
# Columns: [Type, Days for shipping (real), Days for shipment (scheduled), Benefit per order, Sales per customer, Customer Id, Order City, Order Country, Order Customer Id, order date (DateOrders), Order Id, Order Item Discount, Order Item Discount Rate, Order Item Id, Order Item Product Price, Order Item Profit Ratio, Order Item Quantity, Sales, Order Item Total, Order Profit Per Order, Order Region, Delivery Status, Late_delivery_risk, Customer State, Customer Street, Customer Zipcode, Customer City, Customer Country, Order Status, Product Card Id, Product Category Id, Product Image, Product Name, Product Price, shipping date (DateOrders), Shipping Mode]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180508 entries, 0 to 180518
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180508 non-null  object
#  1   Days for shipping (real)       180508 non-null  int64
#  2   Days for shipment (scheduled)  180508 non-null  int64
#  3   Benefit per order              180508 non-null  float64
#  4   Sales per customer             180508 non-null  float64
#  5   Customer Id                    180508 non-null  int64
#  6   Order City                     180508 non-null  object
#  7   Order Country                  180508 non-null  object
#  8   Order Customer Id              180508 non-null  int64
#  9   order date (DateOrders)        180508 non-null  object
#  10  Order Id                       180508 non-null  int64
#  11  Order Item Discount            180508 non-null  float64
# ...

# %%
df.boxplot(column=["Benefit per order"])

# %%
df=df[df["Benefit per order"]>-1500]

# %% [markdown]
# ## ***1) List all the cities and the respective number of pending orders in 'India'?***

# %%
x=df[(df["Order Country"]=="India") & (df["Order Status"]=="PENDING")]

# %%
print(f"number of pending orders with respect to cities\n", x[x['Order Status']=="PENDING"]['Order City'].value_counts())
# Out:
# number of pending orders with respect to cities
#  Kanpur          25
# Bangalore       24
# Pune            24
# Lucknow         21
# Mumbai          18
#                 ..
# Hubli            1
# Aurangabad       1
# Vadodara         1
# Ichalkaranji     1
# Chandigarh       1
# Name: Order City, Length: 91, dtype: int64

# %%
x[['Order City','Order Status']]
# Out:
#          Order City Order Status
# 1           Bikaner      PENDING
# 21         Jabalpur      PENDING
# 45        Bangalore      PENDING
# 46        Bangalore      PENDING
# 382            Pune      PENDING
# ...             ...          ...
# 180142  Bhubaneswar      PENDING
# 180164         Agra      PENDING
# 180248        Dewas      PENDING
# 180331        Ajmer      PENDING
# 180405        Patna      PENDING
#
# [537 rows x 2 columns]

# %% [markdown]
# ## ***3) Which product(s) has/have the maximum discount?***

# %%
df["Order Item Discount"].max()
# Out:
# 500.0

# %%
dis=df.sort_values('Order Item Discount')

# %%
print(f"This Product has the maximum Discount----",dis["Product Name"].tail(1))
# Out:
# This Product has the maximum Discount---- 12606    SOLE E35 Elliptical
# Name: Product Name, dtype: object

# %% [markdown]
# ## ***2) Which country has the most suspected fraud?***

# %%
highfraud=df[(df['Order Status']=='SUSPECTED_FRAUD')&(df['Type']=='TRANSFER')]
highfraud=highfraud[['Order Region']]

# %%
highfraud.head(10)
# Out:
#      Order Region
# 10   Eastern Asia
# 24        Oceania
# 183    US Center
# 184  West of USA
# 185  West of USA
# 186  West of USA
# 187  West of USA
# 188  West of USA
# 189   East of USA
# 190    US Center

# %%
valuecounts=highfraud["Order Region"].value_counts()

# %%
z1=valuecounts.to_dict()
highfraud["fraudcounts"]=highfraud["Order Region"].map(z1)

# %%
highfraud.sort_values("fraudcounts").tail(1)
# Out:
#          Order Region  fraudcounts
# 15367  Western Europe          705

# %% [markdown]
# ## ***4) Which year had the minimum sales for "Nike" products?***

# %%
df['order_year']= pd.DatetimeIndex(df['order date (DateOrders)']).year

# %%
df.head(5)
# Out:
#        Type  Days for shipping (real)  ...   Shipping Mode  order_year
# 0     DEBIT                         3  ...  Standard Class        2018
# 1  TRANSFER                         5  ...  Standard Class        2018
# 2      CASH                         4  ...  Standard Class        2018
# 3     DEBIT                         3  ...  Standard Class        2018
# 4   PAYMENT                         2  ...  Standard Class        2018
#
# [5 rows x 37 columns]

# %%
	df2=df[['order_year','Sales','Product Name']]

# %%
df2=df2[df2['Product Name'].str.contains("Nike")]

# %%
df2.head(5)
# Out:
#     order_year       Sales                          Product Name
# 50        2016  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 52        2016  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 53        2016  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 54        2015  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 59        2016  299.970001     Nike Men's Free 5.0+ Running Shoe

# %%
c=df2[['Sales','order_year','Product Name']].value_counts()
# Out:
# Sales       order_year  Product Name
# 129.990005  2016        Nike Men's CJ Elite 2 TD Football Cleat          8188
#             2015        Nike Men's CJ Elite 2 TD Football Cleat          7932
#             2017        Nike Men's CJ Elite 2 TD Football Cleat          6126
# 50.000000   2016        Nike Men's Dri-FIT Victory Golf Polo             1652
# 150.000000  2015        Nike Men's Dri-FIT Victory Golf Polo             1553
#                                                                          ...
# 89.980003   2017        Nike Men's Comfort 2 Slide                          6
# 125.000000  2017        Nike Women's Legend V-Neck T-Shirt                  5
# 150.000000  2017        Nike Men's Deutschland Weltmeister Winners Bl       3
# 88.000000   2017        Nike Dri-FIT Crew Sock 6 Pack                       3
# 75.000000   2017        Nike Women's Legend V-Neck T-Shirt                  1
# Length: 125, dtype: int64

# %%
result_df=c[(c['Sales']==c['Sales'].min()) & c['order_year']]

# %%
result_df.head(5)
# Out:
#       order_year  Sales                   Product Name
# 2571        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2575        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2576        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2587        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2591        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack

# %%
result_df[['order_year']].value_counts()
# Out:
# 8

# %% [markdown]
# ## ***5) How many successfully processed orders have days for shipping real (Real) > Days for shipment (Scheduled)?***

# %%
df=df.rename(columns={"Days for shipping (real)":"Real_shipping","Days for shipment (scheduled)":"Scheduled_shipping"})

# %%
df.head(2)
# Out:
#        Type  Real_shipping  ...   Shipping Mode  order_year
# 0     DEBIT              3  ...  Standard Class        2018
# 1  TRANSFER              5  ...  Standard Class        2018
#
# [2 rows x 37 columns]

# %%
late_df=df[((df["Real_shipping"])>(df["Scheduled_shipping"]))&(df["Order Status"]=="COMPLETE")]

# %%
late_df=late_df[["Real_shipping","Scheduled_shipping","Order Status"]]

# %%
late_df.head(5)
# Out:
#     Real_shipping  Scheduled_shipping Order Status
# 6               2                   1     COMPLETE
# 13              2                   1     COMPLETE
# 15              2                   1     COMPLETE
# 18              2                   1     COMPLETE
# 25              6                   2     COMPLETE

# %%
late_df.shape[0]
# Out:
# 34194
